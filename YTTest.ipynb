# %%
from ytmusicapi import YTMusic as yt
import pandas as pd

# %%
ytmusic = yt('headers_auth.json')

# %%
tt = ytmusic.get_library_playlists()

# %%
pltest = ytmusic.get_playlist('PLLT7phSFVy-lfNrRTXR_A_HiIpjL5IAEz')

# %%
ytmusic.get_user("UCDDNeReFmDnajCBeq6zKkHQ")
# Out:
# {'name': 'Ruchit Tripathi',
#  'playlists': {'browseId': None,
#   'results': [{'title': "Ruchit's Top hits",
#     'playlistId': 'PLcxbKUGUw9CjHGGC78l0DgeZqLgulEOT-',
#     'thumbnails': [{'url': 'https://yt3.ggpht.com/iTK75l-trwculrJKLRsiqyzRcSGcs5tOsCMyCtI0t0KPEeafRsa2_7fvYBThW5Zq1seYL1F3Ly7N=s192',
#       'width': 192,
#       'height': 192},
#      {'url': 'https://yt3.ggpht.com/iTK75l-trwculrJKLRsiqyzRcSGcs5tOsCMyCtI0t0KPEeafRsa2_7fvYBThW5Zq1seYL1F3Ly7N=s576',
#       'width': 576,
#       'height': 576}]}]}}

# %%
pl = ytmusic.get_playlist('PLcxbKUGUw9CjHGGC78l0DgeZqLgulEOT-')
pl
# Out:
# {'id': 'PLcxbKUGUw9CjHGGC78l0DgeZqLgulEOT-',
#  'privacy': 'PUBLIC',
#  'title': "Ruchit's Top hits",
#  'thumbnails': [{'url': 'https://yt3.ggpht.com/iTK75l-trwculrJKLRsiqyzRcSGcs5tOsCMyCtI0t0KPEeafRsa2_7fvYBThW5Zq1seYL1F3Ly7N=s192',
#    'width': 192,
#    'height': 192},
#   {'url': 'https://yt3.ggpht.com/iTK75l-trwculrJKLRsiqyzRcSGcs5tOsCMyCtI0t0KPEeafRsa2_7fvYBThW5Zq1seYL1F3Ly7N=s576',
#    'width': 576,
#    'height': 576},
#   {'url': 'https://yt3.ggpht.com/iTK75l-trwculrJKLRsiqyzRcSGcs5tOsCMyCtI0t0KPEeafRsa2_7fvYBThW5Zq1seYL1F3Ly7N=s1200',
#    'width': 1200,
#    'height': 1200}],
#  'author': {'name': 'Ruchit Tripathi', 'id': 'UCDDNeReFmDnajCBeq6zKkHQ'},
#  'year': '2020',
#  'duration': '6+ hours',
#  'trackCount': 187,
#  'tracks': [{'videoId': 'HvropLxYb5c',
#    'title': 'Footloose (From "Footloose" Soundtrack)',
#    'artists': [{'name': 'Kenny Loggins', 'id': 'UCF-DjS6Y9CKZThQf01SYe7w'}],
#    'album': {'name': "Footloose (15th Anniversary Collectors' Edition)",
# ...

# %%
song_list = pl['tracks']
song_list
# Out:
# [{'videoId': 'HvropLxYb5c',
#   'title': 'Footloose (From "Footloose" Soundtrack)',
#   'artists': [{'name': 'Kenny Loggins', 'id': 'UCF-DjS6Y9CKZThQf01SYe7w'}],
#   'album': {'name': "Footloose (15th Anniversary Collectors' Edition)",
#    'id': 'MPREb_04te88CNvtj'},
#   'likeStatus': 'INDIFFERENT',
#   'thumbnails': [{'url': 'https://lh3.googleusercontent.com/sYwKGkGzYd0eczgsbRwd6-OWhWSJY1j5jWMWI05GDbxb8pMfOHWH2qXYciOr0Ankzq0BYGW2QDSMeJYH=w60-h60-l90-rj',
#     'width': 60,
#     'height': 60},
#    {'url': 'https://lh3.googleusercontent.com/sYwKGkGzYd0eczgsbRwd6-OWhWSJY1j5jWMWI05GDbxb8pMfOHWH2qXYciOr0Ankzq0BYGW2QDSMeJYH=w120-h120-l90-rj',
#     'width': 120,
#     'height': 120}],
#   'isAvailable': True,
#   'isExplicit': False,
#   'duration': '3:47',
#   'feedbackTokens': {'add': 'AB9zfpJ-Q2Hxg6AxRq09bFpCXYC-CLjGXDclIevcmAwvIdZhjyXGBp2zlnz8xI90OUW5kFXmZgS6MTxjfHZnhnJ8cAAmicZeDA',
# ...

# %%
for track in song_list:
